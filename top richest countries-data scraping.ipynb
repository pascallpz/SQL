# %%
import requests
from bs4 import BeautifulSoup
import openpyxl
source=requests.get('https://www.gfmag.com/global-data/economic-data/worlds-richest-and-poorest-countries')
soup=BeautifulSoup(source.text, 'html.parser')

# %%
list=soup.find('table',border='0').find('tbody')

# %%
x=list.find_all('tr')
len(x)
# Out:
# 194

# %%
val=[]
for rows in x:
    val.append(rows.text.strip().replace('\n','    '))

# %%
val
# Out:
# ['1    Ireland    145,196',
#  '2    Luxembourg    142,490',
#  '3    Singapore    133,895',
#  '4    Qatar    124,848',
#  '5    Macao SAR    89,558',
#  '6    United Arab Emirates    88,221',
#  '7    Switzerland    87,963',
#  '8    Norway    82,655',
#  '9    United States    80,035',
#  '10    San Marino    78,926',
#  '11    Brunei Darussalam    75,583',
#  '12    Hong Kong SAR    74,598',
#  '13    Denmark    73,386',
#  '14    Taiwan    73,344',
#  '15    Netherlands    72,973',
#  '16    Iceland    69,779',
#  '17    Austria    69,502',
#  '18    Andorra    68,998',
#  '19    Germany    66,132',
#  '20    Sweden    65,842',
#  '21    Belgium    65,501',
#  '22    Australia    65,366',
#  '23    Saudi Arabia    64,836',
#  '24    Malta    61,939',
#  '25    Finland    60,897',
#  '26    Guyana    60,648',
#  '27    Bahrain    60,596',
#  '28    Canada    60,177',
#  '29    France    58,828',
#  '30    South Korea    56,706',
#  '31    United Kingdom    56,471',
# ...
